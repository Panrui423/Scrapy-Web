# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import pandas as pd

headers = {
    'Host': 'api.astronauts.id',
    'accept': 'application/json, text/plain, */*',
    'x-session-id': '6c31b24da5884766bfeda6a60fc59463',
    'x-device': 'ios',
    'accept-language': 'en-US,en;q=0.9',
    'x-api-version': '1.9.4',
    'user-agent': 'Astro/202208041744 CFNetwork/1331.0.7 Darwin/21.4.0',
    'x-device-id': '922E6BBB-6A76-46B4-B9D7-FCC3DD31C7B7',
    'x-app-version': 'ios-1.27.1',
    'x-datadog-origin': 'rum',
}

# %%
params = {
    'pageSize': '21',
    'pageIndex': '0',
    'categoryId': '163',
}

# 下一个pageIndex变为1

# %%
response = requests.get('https://api.astronauts.id/api/product/location/0', params=params, headers=headers,verify=False)
# Out:
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
a = response.json()

# %%
a
# Out:
# {'content': [{'product_id': 4807,
#    'product_name': 'Kurma Ajwa Jumbo 500gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Kurma_Ajwa_Jumbo_500gr_1647651275802_PRODUCT_240x240.png',
#    'product_price': '90800',
#    'product_stock': 27,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1000.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 4806,
#    'product_name': 'Kurma BAM 500gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Kurma_BAM_500gr_1649393219997_PRODUCT_240x240.png',
#    'product_price': '40300',
#    'product_stock': 16,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1000.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 600,
#    'product_name': 'Pisang Cavendish Conventional 500gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Pisang_Cavendish_Conventional_500gr_1657853345927_PRODUCT_240x240.png',
#    'product_price': '11500',
#    'product_stock': 29,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 322.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 6,
#    'product_name': 'Alpukat Mentega Regular 1kg',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Alpukat_Mentega_Super_1kg_240x240.png',
#    'product_price': '39500',
#    'product_stock': 1,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1000.0,
#    'product_weight': '1000',
#    'astro_coin': 0},
#   {'product_id': 583,
#    'product_name': 'Lemon Import 500gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Lemon_Import_500gr_PRODUCT_1646536053251_240x240.png',
#    'product_price': '29400',
#    'product_stock': 4,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 4500.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 49,
#    'product_name': 'Semangka Merah 1 pcs',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Semangka_Merah_1_pcs_240x240.png',
#    'product_price': '55400',
#    'product_stock': 3,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 3672.0,
#    'product_weight': '200',
#    'astro_coin': 0},
#   {'product_id': 437,
#    'product_name': 'Anggur Red Globe 500gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Anggur_Red_Globe_500gr_240x240.png',
#    'product_price': '39900',
#    'product_stock': 7,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1400.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 480,
#    'product_name': 'Apel Fuji 1kg',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Apel_Fuji_1kg_1650351718164_PRODUCT_240x240.png',
#    'product_price': '57900',
#    'product_stock': 6,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 4500.0,
#    'product_weight': '1000',
#    'astro_coin': 0},
#   {'product_id': 777,
#    'product_name': 'Buah Naga Merah 1 pcs',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Buah_Naga_Merah_1_pcs_1648001954961_PRODUCT_240x240.png',
#    'product_price': '17900',
#    'product_stock': 19,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1000.0,
#    'product_weight': '200',
#    'astro_coin': 0},
#   {'product_id': 90,
#    'product_name': 'Jambu Kristal Sunpride 1 Pack',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Jambu_Kristal_Sunpride_500gr_240x240.png',
#    'product_price': '17900',
#    'product_stock': 2,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 1105102,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 2,
#    'product_volume': 308.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 2075,
#    'product_name': 'Jeruk Mandarin Wokam 750gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Jeruk_Mandarin_Wokam_750gr_1650361078025_PRODUCT_240x240.png',
#    'product_price': '47900',
#    'product_stock': 1,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1200.0,
#    'product_weight': '800',
#    'astro_coin': 0},
#   {'product_id': 190,
#    'product_name': 'Jeruk Medan 500gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Jeruk_Medan_500gr_1650360950670_PRODUCT_240x240.png',
#    'product_price': '23200',
#    'product_stock': 4,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1000.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 630,
#    'product_name': 'Jeruk Nipis 250gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Jeruk_Nipis_250gr_1650360975065_PRODUCT_240x240.png',
#    'product_price': '5900',
#    'product_stock': 2,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1000.0,
#    'product_weight': '250',
#    'astro_coin': 0},
#   {'product_id': 113,
#    'product_name': 'Lemon California 500gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Lemon_California_Kuning_500gr_PRODUCT_1646536006519_240x240.png',
#    'product_price': '11500',
#    'product_stock': 9,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 1105100,
#    'product_discount_price': '6900',
#    'product_discount_percentage': '40%',
#    'product_discount_stock': 3,
#    'product_discount_daily_quota': 2,
#    'product_volume': 4500.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 612,
#    'product_name': 'Pepaya California Conventional 1 pcs',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Pepaya_California_Conventional_1_pcs_240x240.png',
#    'product_price': '19500',
#    'product_stock': 5,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1863.0,
#    'product_weight': '1300',
#    'astro_coin': 0},
#   {'product_id': 1935,
#    'product_name': 'Pir Xiang Lie 500gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Pir_Xiang_Lie_500gr_1650363020850_PRODUCT_240x240.png',
#    'product_price': '35800',
#    'product_stock': 3,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 2000.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 796,
#    'product_name': 'Pisang Tanduk 2 pcs',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Pisang_Tanduk_2_pcs_240x240.png',
#    'product_price': '14300',
#    'product_stock': 3,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1000.0,
#    'product_weight': '200',
#    'astro_coin': 0},
#   {'product_id': 237,
#    'product_name': 'Astro Goods Strawberry Lokal Super 250gr',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Strawberry_Lokal_Super_250gr_1657852861124_PRODUCT_240x240.png',
#    'product_price': '25900',
#    'product_stock': 17,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1050.0,
#    'product_weight': '250',
#    'astro_coin': 0},
#   {'product_id': 6922,
#    'product_name': 'Jambu Kristal Sunpride 1kg',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Jambu_Kristal_Sunpride_1kg_1659934500387_PRODUCT_240x240.png',
#    'product_price': '25400',
#    'product_stock': 1,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1000.0,
#    'product_weight': '1000',
#    'astro_coin': 0},
#   {'product_id': 6757,
#    'product_name': 'Anggur Black Magic Mesir 1 Pack',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Anggur_Black_Magic_Mesir_1_Pack_1659058530194_PRODUCT_240x240.png',
#    'product_price': '62500',
#    'product_stock': 1,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 2112.0,
#    'product_weight': '500',
#    'astro_coin': 0},
#   {'product_id': 6632,
#    'product_name': 'Buah Delima Peru 1 pcs',
#    'product_url_image': 'https://storage.googleapis.com/indo-astro/Buah_Delima_Peru_1_pcs_1658469286327_PRODUCT_240x240.png',
#    'product_price': '61700',
#    'product_stock': 2,
#    'product_favorite': False,
#    'is_twenty_one': False,
#    'product_inventory_discount_id': 0,
#    'product_discount_price': '',
#    'product_discount_percentage': '',
#    'product_discount_stock': 0,
#    'product_discount_daily_quota': 0,
#    'product_volume': 1200.0,
#    'product_weight': '200',
#    'astro_coin': 0}],
#  'pageable': {'sort': {'sorted': False, 'unsorted': True, 'empty': True},
#   'pageSize': 21,
#   'pageNumber': 0,
#   'offset': 0,
#   'unpaged': False,
#   'paged': True},
#  'totalPages': 3,
#  'totalElements': 63,
#  'last': False,
#  'first': True,
#  'sort': {'sorted': False, 'unsorted': True, 'empty': True},
#  'numberOfElements': 21,
#  'size': 21,
#  'number': 0,
#  'empty': False}

# %%
a['content'][0]['product_name']
# Out:
# {'product_id': 4807,
#  'product_name': 'Kurma Ajwa Jumbo 500gr',
#  'product_url_image': 'https://storage.googleapis.com/indo-astro/Kurma_Ajwa_Jumbo_500gr_1647651275802_PRODUCT_240x240.png',
#  'product_price': '90800',
#  'product_stock': 27,
#  'product_favorite': False,
#  'is_twenty_one': False,
#  'product_inventory_discount_id': 0,
#  'product_discount_price': '',
#  'product_discount_percentage': '',
#  'product_discount_stock': 0,
#  'product_discount_daily_quota': 0,
#  'product_volume': 1000.0,
#  'product_weight': '500',
#  'astro_coin': 0}

# %%
# Out:
# 21

# %%
next_params = params
# 创建一个空的 DataFrame
df_all = pd.DataFrame(columns=['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight'])
j=0
while next_params:
    response = requests.get('https://api.astronauts.id/api/product/location/0', params=next_params, headers=headers, verify=False)
    response.status_code
    data = response.json()
    if 'content' in data:
        length_data = len(data['content'])
    else:
        break
    product_name = {}
    product_url_image = {}
    product_price = {}
    product_stock = {}
    product_volume = {}
    product_weight = {}

    for i in range(length_data):
        product_name[i] = data['content'][i]['product_name']
        product_url_image[i] = data['content'][i]['product_url_image']
        product_price[i] = data['content'][i]['product_price']
        product_stock[i] = data['content'][i]['product_stock']
        product_volume[i] = data['content'][i]['product_volume']
        product_weight[i] = data['content'][i]['product_weight']
        
    product_name = pd.DataFrame.from_dict(product_name,orient='index')
    product_url_image = pd.DataFrame.from_dict(product_url_image,orient='index')
    product_price = pd.DataFrame.from_dict(product_price,orient='index')
    product_stock = pd.DataFrame.from_dict(product_stock,orient='index')
    product_volume = pd.DataFrame.from_dict(product_volume,orient='index')   
    product_weight = pd.DataFrame.from_dict(product_weight,orient='index') 
                       
    frames = [product_name, product_url_image, product_price, product_stock, product_volume, product_weight]
    df = pd.concat(frames,axis = 1)
    df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
    df.index = list(range(0 + j*21, 21+j*21, 1))
    df_f = [df_all,df]
    df_all = pd.concat(df_f)
    next_params['pageIndex'] = str(j+1)
    j = j+1
# Out:
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kq/h0gtgyt15876hcqgj3_277v80000gn/T/ipykernel_97933/2675355119.py in <module>
#      36     df = pd.concat(frames,axis = 1)
#      37     df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
# ---> 38     df.index = list(range(0 + j*21, 21+j*21, 1))
#      39     df_f = [df_all,df]
#      40     df_all = pd.concat(df_f)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 21 elements

# %%
df_all
# Out:
#                            product_name  \
# 0                Kurma Ajwa Jumbo 500gr
# 1                       Kurma BAM 500gr
# 2   Pisang Cavendish Conventional 500gr
# 3           Alpukat Mentega Regular 1kg
# 4                    Lemon Import 500gr
# ..                                  ...
# 58              Sunkist Navel Jumbo 1kg
# 59                Pear Pakam Afrika 1kg
# 60              Pisang Frui Baby 1 Pack
# 61              Puree Jambu Merah 500gr
# 62                Melon Inthanon Size M
#
#                                     product_url_image product_price  \
# 0   https://storage.googleapis.com/indo-astro/Kurm...         90800
# 1   https://storage.googleapis.com/indo-astro/Kurm...         40300
# 2   https://storage.googleapis.com/indo-astro/Pisa...         11500
# 3   https://storage.googleapis.com/indo-astro/Alpu...         39500
# 4   https://storage.googleapis.com/indo-astro/Lemo...         29400
# ..                                                ...           ...
# 58  https://storage.googleapis.com/indo-astro/Sunk...         69700
# 59  https://storage.googleapis.com/indo-astro/Pear...         42000
# 60  https://storage.googleapis.com/indo-astro/Pisa...         10500
# 61  https://storage.googleapis.com/indo-astro/Pure...         24500
# 62  https://storage.googleapis.com/indo-astro/Melo...         48000
#
#    product_stock  product_volume product_weight
# 0             27          1000.0            500
# 1             16          1000.0            500
# 2             29           322.0            500
# 3              1          1000.0           1000
# 4              4          4500.0            500
# ..           ...             ...            ...
# 58             0          3600.0           1000
# 59             0          1000.0           1000
# 60             0          1000.0            500
# 61             0          1000.0            500
# 62             0          1000.0           1000
#
# [63 rows x 6 columns]

# %%
df_all.to_csv('Astroproduct.csv') # Buah

# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import pandas as pd

# Sayur Hijau
headers = {
    'Host': 'api.astronauts.id',
    'accept': 'application/json, text/plain, */*',
    'x-session-id': '6c31b24da5884766bfeda6a60fc59463',
    'x-device': 'ios',
    'accept-language': 'en-US,en;q=0.9',
    'x-api-version': '1.9.4',
    'user-agent': 'Astro/202208041744 CFNetwork/1331.0.7 Darwin/21.4.0',
    'x-device-id': '922E6BBB-6A76-46B4-B9D7-FCC3DD31C7B7',
    'x-app-version': 'ios-1.27.1',
    'x-datadog-origin': 'rum',
    'Connection':'close',
}

params = {
    'pageSize': '21',
    'pageIndex': '0',
    'categoryId': '164',
}

# %%
next_params = params
# 创建一个空的 DataFrame
df_all = pd.DataFrame(columns=['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight'])
j=0
while next_params:
    response = requests.get('https://api.astronauts.id/api/product/location/0', params=next_params, headers=headers, verify=False)
    response.status_code
    data = response.json()
    if 'content' in data:
        length_data = len(data['content'])
    else:
        break
    product_name = {}
    product_url_image = {}
    product_price = {}
    product_stock = {}
    product_volume = {}
    product_weight = {}

    for i in range(length_data):
        product_name[i] = data['content'][i]['product_name']
        product_url_image[i] = data['content'][i]['product_url_image']
        product_price[i] = data['content'][i]['product_price']
        product_stock[i] = data['content'][i]['product_stock']
        product_volume[i] = data['content'][i]['product_volume']
        product_weight[i] = data['content'][i]['product_weight']
        
    product_name = pd.DataFrame.from_dict(product_name,orient='index')
    product_url_image = pd.DataFrame.from_dict(product_url_image,orient='index')
    product_price = pd.DataFrame.from_dict(product_price,orient='index')
    product_stock = pd.DataFrame.from_dict(product_stock,orient='index')
    product_volume = pd.DataFrame.from_dict(product_volume,orient='index')   
    product_weight = pd.DataFrame.from_dict(product_weight,orient='index') 
                       
    frames = [product_name, product_url_image, product_price, product_stock, product_volume, product_weight]
    df = pd.concat(frames,axis = 1)
    df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
    df.index = list(range(0 + j*21, 21+j*21, 1))
    df_f = [df_all,df]
    df_all = pd.concat(df_f)
    next_params['pageIndex'] = str(j+1)
    j = j+1
# Out:
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kq/h0gtgyt15876hcqgj3_277v80000gn/T/ipykernel_97933/2675355119.py in <module>
#      36     df = pd.concat(frames,axis = 1)
#      37     df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
# ---> 38     df.index = list(range(0 + j*21, 21+j*21, 1))
#      39     df_f = [df_all,df]
#      40     df_all = pd.concat(df_f)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 12 elements, new values have 21 elements

# %%
df_all20 = df_all

# %%
df_all
# Out:
#                 product_name  \
# 0          Baby Buncis 250gr
# 1              Brokoli Besar
# 2         Buncis Super 250gr
# 3          Jagung Acar 250gr
# 4         Jamur Kuping 250gr
# ..                       ...
# 58         Tomat Hijau 250gr
# 59  Terong Hijau Lalap 250gr
# 60                Pare 500gr
# 61          Daun Pandan 50gr
# 62              Zukini 500gr
#
#                                     product_url_image product_price  \
# 0   https://storage.googleapis.com/indo-astro/Baby...         11800
# 1   https://storage.googleapis.com/indo-astro/Brok...         24900
# 2   https://storage.googleapis.com/indo-astro/Bunc...          6700
# 3   https://storage.googleapis.com/indo-astro/Jagu...          8500
# 4   https://storage.googleapis.com/indo-astro/Jamu...          8900
# ..                                                ...           ...
# 58  https://storage.googleapis.com/indo-astro/Toma...          6000
# 59  https://storage.googleapis.com/indo-astro/Tero...          5900
# 60  https://storage.googleapis.com/indo-astro/Pare...         11200
# 61  https://storage.googleapis.com/indo-astro/Daun...          2000
# 62  https://storage.googleapis.com/indo-astro/Zuki...         12500
#
#    product_stock  product_volume product_weight
# 0              3          1000.0            250
# 1              1          1000.0            500
# 2              5          1000.0            250
# 3             10           600.0            250
# 4              1          2415.0            200
# ..           ...             ...            ...
# 58             0          1014.0            250
# 59             0          2640.0            250
# 60             0          4500.0            500
# 61             0          1000.0             50
# 62             0          1000.0            500
#
# [63 rows x 6 columns]

# %%
df_all.to_csv('Astro_Sayur_product.csv') # Buah

# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import pandas as pd

# Bawang & Rempah
headers = {
    'Host': 'api.astronauts.id',
    'accept': 'application/json, text/plain, */*',
    'x-session-id': '6c31b24da5884766bfeda6a60fc59463',
    'x-device': 'ios',
    'accept-language': 'en-US,en;q=0.9',
    'x-api-version': '1.9.4',
    'user-agent': 'Astro/202208041744 CFNetwork/1331.0.7 Darwin/21.4.0',
    'x-device-id': '922E6BBB-6A76-46B4-B9D7-FCC3DD31C7B7',
    'x-app-version': 'ios-1.27.1',
    'x-datadog-origin': 'rum',
    'Connection':'close',
}

params = {
    'pageSize': '21',
    'pageIndex': '0',
    'categoryId': '166',
}

# %%
next_params = params
# 创建一个空的 DataFrame
df_all = pd.DataFrame(columns=['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight'])
j=0
while next_params:
    response = requests.get('https://api.astronauts.id/api/product/location/0', params=next_params, headers=headers, verify=False)
    response.status_code
    data = response.json()
    if 'content' in data:
        length_data = len(data['content'])
    else:
        break
    product_name = {}
    product_url_image = {}
    product_price = {}
    product_stock = {}
    product_volume = {}
    product_weight = {}

    for i in range(length_data):
        product_name[i] = data['content'][i]['product_name']
        product_url_image[i] = data['content'][i]['product_url_image']
        product_price[i] = data['content'][i]['product_price']
        product_stock[i] = data['content'][i]['product_stock']
        product_volume[i] = data['content'][i]['product_volume']
        product_weight[i] = data['content'][i]['product_weight']
        
    product_name = pd.DataFrame.from_dict(product_name,orient='index')
    product_url_image = pd.DataFrame.from_dict(product_url_image,orient='index')
    product_price = pd.DataFrame.from_dict(product_price,orient='index')
    product_stock = pd.DataFrame.from_dict(product_stock,orient='index')
    product_volume = pd.DataFrame.from_dict(product_volume,orient='index')   
    product_weight = pd.DataFrame.from_dict(product_weight,orient='index') 
                       
    frames = [product_name, product_url_image, product_price, product_stock, product_volume, product_weight]
    df = pd.concat(frames,axis = 1)
    df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
    df_all_shape = df_all.shape[0]
    df.index = list(range(df_all_shape, df_all_shape+df.shape[0], 1))
    df_f = [df_all,df]
    df_all = pd.concat(df_f)
    next_params['pageIndex'] = str(j+1)
    j = j+1
# Out:
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kq/h0gtgyt15876hcqgj3_277v80000gn/T/ipykernel_97933/2875106954.py in <module>
#      35     frames = [product_name, product_url_image, product_price, product_stock, product_volume, product_weight]
#      36     df = pd.concat(frames,axis = 1)
# ---> 37     df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
#      38     df_all_shape = df_all.shape[0]
#      39     df.index = list(range(df_all_shape, df_all_shape+df.shape[0], 1))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 6 elements

# %%
df_all.to_csv('Astro_Bewang_&_Rempah_product.csv') #  Bawang & Rempah

# %%
df_all
# Out:
#                       product_name  \
# 0                 Jahe Merah 200gr
# 1           Cabe Hijau Besar 150gr
# 2   Bawang Putih Kating Pack 250gr
# 3        Cabe Merah Keriting 150gr
# 4           Cabe Merah Rawit 150gr
# 5         Bawang Merah Super 250gr
# 6                 Jahe Merah 200gr
# 7           Cabe Hijau Besar 150gr
# 8   Bawang Putih Kating Pack 250gr
# 9        Cabe Merah Keriting 150gr
# 10          Cabe Merah Rawit 150gr
# 11        Bawang Merah Super 250gr
#
#                                     product_url_image product_price  \
# 0   https://storage.googleapis.com/indo-astro/Jahe...          7000
# 1   https://storage.googleapis.com/indo-astro/Cabe...         11200
# 2   https://storage.googleapis.com/indo-astro/Bawa...         12000
# 3   https://storage.googleapis.com/indo-astro/Cabe...         19900
# 4   https://storage.googleapis.com/indo-astro/Cabe...         15900
# 5   https://storage.googleapis.com/indo-astro/Bawa...         22900
# 6   https://storage.googleapis.com/indo-astro/Jahe...          7000
# 7   https://storage.googleapis.com/indo-astro/Cabe...         11200
# 8   https://storage.googleapis.com/indo-astro/Bawa...         12000
# 9   https://storage.googleapis.com/indo-astro/Cabe...         19900
# 10  https://storage.googleapis.com/indo-astro/Cabe...         15900
# 11  https://storage.googleapis.com/indo-astro/Bawa...         22900
#
#    product_stock  product_volume product_weight
# 0             12          1000.0            200
# 1              2          1000.0            150
# 2              6          1000.0            250
# 3              4           308.0            150
# 4              2           308.0            150
# 5              0          1000.0            250
# 6             12          1000.0            200
# 7              2          1000.0            150
# 8              6          1000.0            250
# 9              4           308.0            150
# 10             2           308.0            150
# 11             0          1000.0            250

# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import pandas as pd

# organik
headers = {
    'Host': 'api.astronauts.id',
    'accept': 'application/json, text/plain, */*',
    'x-session-id': '6c31b24da5884766bfeda6a60fc59463',
    'x-device': 'ios',
    'accept-language': 'en-US,en;q=0.9',
    'x-api-version': '1.9.4',
    'user-agent': 'Astro/202208041744 CFNetwork/1331.0.7 Darwin/21.4.0',
    'x-device-id': '922E6BBB-6A76-46B4-B9D7-FCC3DD31C7B7',
    'x-app-version': 'ios-1.27.1',
    'x-datadog-origin': 'rum',
    'Connection':'close',
}

params = {
    'pageSize': '21',
    'pageIndex': '0',
    'categoryId': '167',
}

# %%
next_params = params
# 创建一个空的 DataFrame
df_all = pd.DataFrame(columns=['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight'])
j=0
while next_params:
    response = requests.get('https://api.astronauts.id/api/product/location/0', params=next_params, headers=headers, verify=False)
    response.status_code
    data = response.json()
    if 'content' in data:
        length_data = len(data['content'])
    else:
        break
    product_name = {}
    product_url_image = {}
    product_price = {}
    product_stock = {}
    product_volume = {}
    product_weight = {}

    for i in range(length_data):
        product_name[i] = data['content'][i]['product_name']
        product_url_image[i] = data['content'][i]['product_url_image']
        product_price[i] = data['content'][i]['product_price']
        product_stock[i] = data['content'][i]['product_stock']
        product_volume[i] = data['content'][i]['product_volume']
        product_weight[i] = data['content'][i]['product_weight']
        
    product_name = pd.DataFrame.from_dict(product_name,orient='index')
    product_url_image = pd.DataFrame.from_dict(product_url_image,orient='index')
    product_price = pd.DataFrame.from_dict(product_price,orient='index')
    product_stock = pd.DataFrame.from_dict(product_stock,orient='index')
    product_volume = pd.DataFrame.from_dict(product_volume,orient='index')   
    product_weight = pd.DataFrame.from_dict(product_weight,orient='index') 
                       
    frames = [product_name, product_url_image, product_price, product_stock, product_volume, product_weight]
    df = pd.concat(frames,axis = 1)
    df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
    df_all_shape = df_all.shape[0]
    df.index = list(range(df_all_shape, df_all_shape+df.shape[0], 1))
    df_f = [df_all,df]
    df_all = pd.concat(df_f)
    next_params['pageIndex'] = str(j+1)
    j = j+1
# Out:
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/ruipan/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.astronauts.id'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kq/h0gtgyt15876hcqgj3_277v80000gn/T/ipykernel_97933/2875106954.py in <module>
#      35     frames = [product_name, product_url_image, product_price, product_stock, product_volume, product_weight]
#      36     df = pd.concat(frames,axis = 1)
# ---> 37     df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
#      38     df_all_shape = df_all.shape[0]
#      39     df.index = list(range(df_all_shape, df_all_shape+df.shape[0], 1))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 6 elements

# %%
df_all.to_csv('Astro_organik_product.csv') #  organik

# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import pandas as pd

# Minuman

headers = {
    'Host': 'api.astronauts.id',
    'x-datadog-parent-id': '3542696558',
    'accept': 'application/json, text/plain, */*',
    'x-session-id': '6c31b24da5884766bfeda6a60fc59463',
    'x-device': 'ios',
    'x-datadog-trace-id': '791694749',
    'accept-language': 'en-US,en;q=0.9',
    'x-api-version': '1.9.4',
    'user-agent': 'Astro/202208041744 CFNetwork/1331.0.7 Darwin/21.4.0',
    'x-device-id': '922E6BBB-6A76-46B4-B9D7-FCC3DD31C7B7',
    'x-app-version': 'ios-1.27.1',
    'x-datadog-origin': 'rum',
}

params = {
    'pageSize': '21',
    'pageIndex': '0',
    'categoryId': '196',
}

# %%
category = ['197','198','199','200','201','202','203','204','450','195']

# %%
next_params = params
# 创建一个空的 DataFrame
df_all = pd.DataFrame(columns=['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight'])
j=0

for i in category:
    while next_params:
        response = requests.get('https://api.astronauts.id/api/product/location/0', params=next_params, headers=headers, verify=False)
        response.status_code
        data = response.json()
        if 'content' in data & len(data['content']) > 0:
            length_data = len(data['content'])
        else:
            break
        product_name = {}
        product_url_image = {}
        product_price = {}
        product_stock = {}
        product_volume = {}
        product_weight = {}

        for i in range(length_data):
            product_name[i] = data['content'][i]['product_name']
            product_url_image[i] = data['content'][i]['product_url_image']
            product_price[i] = data['content'][i]['product_price']
            product_stock[i] = data['content'][i]['product_stock']
            product_volume[i] = data['content'][i]['product_volume']
            product_weight[i] = data['content'][i]['product_weight']

        product_name = pd.DataFrame.from_dict(product_name,orient='index')
        product_url_image = pd.DataFrame.from_dict(product_url_image,orient='index')
        product_price = pd.DataFrame.from_dict(product_price,orient='index')
        product_stock = pd.DataFrame.from_dict(product_stock,orient='index')
        product_volume = pd.DataFrame.from_dict(product_volume,orient='index')   
        product_weight = pd.DataFrame.from_dict(product_weight,orient='index') 

        frames = [product_name, product_url_image, product_price, product_stock, product_volume, product_weight]
        df = pd.concat(frames,axis = 1)
        df.columns = ['product_name','product_url_image', 'product_price', 'product_stock', 'product_volume', 'product_weight']
        df_all_shape = df_all.shape[0]
        df.index = list(range(df_all_shape, df_all_shape+df.shape[0], 1))
        df_f = [df_all,df]
        df_all = pd.concat(df_f)
        next_params['pageIndex'] = str(j+1)
        j = j+1
    next_params['categoryId'] = i
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     695             if is_new_proxy_conn and http_tunnel_required:
# --> 696                 self._prepare_proxy(conn)
#     697
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     963
# --> 964         conn.connect()
#     965
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     370             # self._tunnel_host below.
# --> 371             self._tunnel()
#     372             # Mark this connection as not reusable
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _tunnel(self)
#     928             self.close()
# --> 929             raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
#     930         while True:
#
# OSError: Tunnel connection failed: 405 Method Not Allowed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.astronauts.id', port=443): Max retries exceeded with url: /api/product/location/0?pageSize=21&pageIndex=0&categoryId=196 (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 405 Method Not Allowed')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# /var/folders/kq/h0gtgyt15876hcqgj3_277v80000gn/T/ipykernel_97933/2053464048.py in <module>
#       6 for i in category:
#       7     while next_params:
# ----> 8         response = requests.get('https://api.astronauts.id/api/product/location/0', params=next_params, headers=headers, verify=False)
#       9         response.status_code
#      10         data = response.json()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     508
#     509             if isinstance(e.reason, _ProxyError):
# --> 510                 raise ProxyError(e, request=request)
#     511
#     512             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPSConnectionPool(host='api.astronauts.id', port=443): Max retries exceeded with url: /api/product/location/0?pageSize=21&pageIndex=0&categoryId=196 (Caused by ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 405 Method Not Allowed')))
